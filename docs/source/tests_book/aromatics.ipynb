# %% [markdown]
# ### Aromatics

# %%
from display import display_case_module

from cases import aromatics_cases

display_case_module(aromatics_cases)
# Out:
#         <div style="border: 1px solid #ccc; padding: 10px; margin-bottom: 20px; border-radius: 5px;">
#             <h3 style="color: #2C3E50;">Identifier: C1=CC2=CC=CC=CC2=C1</h3>
#             <p><strong style="color: #3498DB;">UNIFAC Result:</strong> {'ACH': 8, 'AC': 2}</p>
#             <p><strong style="color: #3498DB;">PSRK Result:</strong> {'ACH': 8, 'AC': 2}</p>
#             <p><strong style="color: #3498DB;">Joback Result:</strong> {'ring=CH-': 8, 'ring=C<': 2}</p>
#             <div style="text-align: center;">
#                 <?xml version='1.0' encoding='iso-8859-1'?>
# <svg version='1.1' baseProfile='full'
#               xmlns='http://www.w3.org/2000/svg'
#                       xmlns:rdkit='http://www.rdkit.org/xml'
#                       xmlns:xlink='http://www.w3.org/1999/xlink'
#                   xml:space='preserve'
# width='400px' height='200px' viewBox='0 0 400 200'>
# <!-- END OF HEADER -->
# ...
